# %%
import matplotlib.pyplot as plt
from fuzzy_expert.variable import FuzzyVariable


variables = {
    "s1": FuzzyVariable(
        universe_range=(0, 120),
        terms={
            "Far": [(40, 0), (100, 1)],
            "Close": [(10, 1),  (40, 0)],
        },
    ),
    "s2": FuzzyVariable(
        universe_range=(0, 120),
        terms={
            "Far": [(40, 0), (100, 1)],
            "Close": [(10, 1),  (40, 0)],
        },
    ),
    "s3": FuzzyVariable(
        universe_range=(0, 120),
        terms={
            "Far": [(40, 0), (100, 1)],
            "Close": [(10, 1),  (40, 0)],
        },
    ),
    "s4": FuzzyVariable(
        universe_range=(0, 120),
        terms={
            "Far": [(40, 0), (100, 1)],
            "Close": [(10, 1),  (40, 0)],
        },
    ),
    "s5": FuzzyVariable(
        universe_range=(0, 120),
        terms={
            "Far": [(40, 0), (100, 1)],
            "Close": [(10, 1),  (40, 0)],
        },
    ),
    "decision": FuzzyVariable(
        universe_range=(-10, 10),
        terms={
            "pos": [(0, 0), (10, 1)],
            "neg": [(-10, 1), (0, 0)],
            "front": [(-3, 0), (0, 1), (3, 0)],
        },
    ),
}

plt.figure(figsize=(10, 5))
# left
plt.subplot(1, 2, 1)
variables["s2"].plot()

plt.subplot(1, 2, 2)
variables["decision"].plot()
plt.title("decision")
# Out:
# Text(0.5, 1.0, 'decision')

# %%
from fuzzy_expert.rule import FuzzyRule

rules = [
    FuzzyRule(
        premise=[
            ("s2" , 'Far'),
            ("AND", "s1", "Close"),

        ],
        consequence=[("decision", "pos")],
    ),
    FuzzyRule(
        premise=[
            ("s3" , 'Close'),
            ("AND", "s2", "Close"),
        ],
        consequence=[("decision", "neg")],
    ),
]

# %%
from fuzzy_expert.inference import DecompositionalInference

model = DecompositionalInference(
    and_operator="min",
    or_operator="max",
    implication_operator="Rc",
    composition_operator="max-min",
    production_link="max",
    defuzzification_operator="cog",
)

model(
    variables=variables,
    rules=rules,
    s2=80,
    s3=30,
    s4=20,
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 12
#       1 from fuzzy_expert.inference import DecompositionalInference
#       3 model = DecompositionalInference(
#       4     and_operator="min",
#       5     or_operator="max",
#    (...)
#       9     defuzzification_operator="cog",
#      10 )
# ---> 12 model(
#      13     variables=variables,
#      14     rules=rules,
#      15     s2=80,
#      16     s3=30,
#      17     s4=20,
#      18 )
#
# File c:\Users\momoein\AppData\Local\Programs\Python\Python311\Lib\site-packages\fuzzy_expert\inference.py:115, in DecompositionalInference.__call__(self, variables, rules, **input_values)
#     113 self._compute_modified_consequence_memberships()
#     114 self._compute_fuzzy_implication()
# --> 115 self._compute_fuzzy_composition()
#     116 self._combine_antecedents()
#     117 self._compute_rule_infered_cf()
#
# File c:\Users\momoein\AppData\Local\Programs\Python\Python311\Lib\site-packages\fuzzy_expert\inference.py:283, in DecompositionalInference._compute_fuzzy_composition(self)
#     278 for consequence_name in rule.modified_consequence_memberships.keys():
#     280     implication = rule.fuzzy_implications[
#     281         (premise_name, consequence_name)
#     282     ]
# --> 283     fact_value = self.fact_values[premise_name]
#     284     n_dim = len(fact_value)
#     285     fact_value = fact_value.reshape((n_dim, 1))
#
# KeyError: 's1'

# %%
from ipywidgets import interact, widgets

def demo(s1, s2, s3, s4, s5):
    plt.figure(figsize=(15,5))
    model.plot(
        rules=rules,
        variables=variables,
        s1=s1,
        s2=s2,
        s3=s3,
        s4=s4,
        s5=s5,
    )

interact(
    demo,
    s1=widgets.FloatSlider(min=0, max=100),
    s2=widgets.FloatSlider(min=0, max=100),
    s3=widgets.FloatSlider(min=0, max=100),
    s4=widgets.FloatSlider(min=0, max=100),
    s5=widgets.FloatSlider(min=0, max=100),
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='s1'), FloatSlider(value=0.0, description='s2'), Floa…
# <function __main__.demo(s1, s2, s3, s4, s5)>
